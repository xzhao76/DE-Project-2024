# %%
import sys
print(sys.executable)
# Out:
# d:\DE-Project-2024\.venv\Scripts\python.exe

# %%
import requests

BASE_API_URL = "https://us-central1-dlthub-analytics.cloudfunctions.net/data_engineering_zoomcamp_api"

page_number = 1
while True:
    params = {'page': page_number}
    response = requests.get(BASE_API_URL, params=params)
    page_data = response.json()

    if not page_data:
        break

    print(page_data)
    page_number += 1

    # limit the number of pages for testing
    if page_number > 2:
      break
# Out:
# [{'End_Lat': 40.742963, 'End_Lon': -73.980072, 'Fare_Amt': 45.0, 'Passenger_Count': 1, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.641525, 'Start_Lon': -73.787442, 'Tip_Amt': 9.0, 'Tolls_Amt': 4.15, 'Total_Amt': 58.15, 'Trip_Distance': 17.52, 'Trip_Dropoff_DateTime': '2009-06-14 23:48:00', 'Trip_Pickup_DateTime': '2009-06-14 23:23:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.740187, 'End_Lon': -74.005698, 'Fare_Amt': 6.5, 'Passenger_Count': 1, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.722065, 'Start_Lon': -74.009767, 'Tip_Amt': 1.0, 'Tolls_Amt': 0.0, 'Total_Amt': 8.5, 'Trip_Distance': 1.56, 'Trip_Dropoff_DateTime': '2009-06-18 17:43:00', 'Trip_Pickup_DateTime': '2009-06-18 17:35:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 1.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.718043, 'End_Lon': -74.004745, 'Fare_Amt': 12.5, 'Passenger_Count': 5, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.761945, 'Start_Lon': -73.983038, 'Tip_Amt': 2.0, 'Tolls_Amt': 0.0, 'Total_Amt': 15.5, 'Trip_Distance': 3.37, 'Trip_Dropoff_DateTime': '2009-06-10 18:27:00', 'Trip_Pickup_DateTime': '2009-06-10 18:08:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 1.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.739637, 'End_Lon': -73.985233, 'Fare_Amt': 4.9, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.749802, 'Start_Lon': -73.992247, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 5.4, 'Trip_Distance': 1.11, 'Trip_Dropoff_DateTime': '2009-06-14 23:58:00', 'Trip_Pickup_DateTime': '2009-06-14 23:54:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.730032, 'End_Lon': -73.852693, 'Fare_Amt': 25.7, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.776825, 'Start_Lon': -73.949233, 'Tip_Amt': 0.0, 'Tolls_Amt': 4.15, 'Total_Amt': 29.85, 'Trip_Distance': 11.09, 'Trip_Dropoff_DateTime': '2009-06-13 13:23:00', 'Trip_Pickup_DateTime': '2009-06-13 13:01:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.777537, 'End_Lon': -73.97686, 'Fare_Amt': 7.3, 'Passenger_Count': 2, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.790582, 'Start_Lon': -73.953652, 'Tip_Amt': 2.0, 'Tolls_Amt': 0.0, 'Total_Amt': 10.3, 'Trip_Distance': 2.1, 'Trip_Dropoff_DateTime': '2009-06-10 19:52:00', 'Trip_Pickup_DateTime': '2009-06-10 19:43:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 1.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.770277, 'End_Lon': -73.962125, 'Fare_Amt': 3.7, 'Passenger_Count': 1, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.767147, 'Start_Lon': -73.966408, 'Tip_Amt': 1.0, 'Tolls_Amt': 0.0, 'Total_Amt': 5.2, 'Trip_Distance': 0.4, 'Trip_Dropoff_DateTime': '2009-06-10 20:09:00', 'Trip_Pickup_DateTime': '2009-06-10 20:06:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.774043, 'End_Lon': -73.951465, 'Fare_Amt': 8.1, 'Passenger_Count': 2, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.76175, 'Start_Lon': -73.977773, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 8.6, 'Trip_Distance': 2.24, 'Trip_Dropoff_DateTime': '2009-06-14 21:08:00', 'Trip_Pickup_DateTime': '2009-06-14 20:57:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.777985, 'End_Lon': -73.943683, 'Fare_Amt': 6.1, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.766355, 'Start_Lon': -73.959832, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 6.1, 'Trip_Distance': 1.48, 'Trip_Dropoff_DateTime': '2009-06-14 12:56:00', 'Trip_Pickup_DateTime': '2009-06-14 12:49:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.720052, 'End_Lon': -74.009823, 'Fare_Amt': 8.9, 'Passenger_Count': 1, 'Paymen ...
# [{'End_Lat': 40.72205, 'End_Lon': -73.990365, 'Fare_Amt': 15.3, 'Passenger_Count': 5, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.76032, 'Start_Lon': -73.962335, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 15.8, 'Trip_Distance': 5.7, 'Trip_Dropoff_DateTime': '2009-06-10 04:50:00', 'Trip_Pickup_DateTime': '2009-06-10 04:35:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.761672, 'End_Lon': -73.997758, 'Fare_Amt': 6.9, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.780502, 'Start_Lon': -73.980268, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 6.9, 'Trip_Distance': 1.77, 'Trip_Dropoff_DateTime': '2009-06-13 09:13:00', 'Trip_Pickup_DateTime': '2009-06-13 09:05:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.770613, 'End_Lon': -73.865242, 'Fare_Amt': 20.1, 'Passenger_Count': 1, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.793433, 'Start_Lon': -73.951623, 'Tip_Amt': 5.02, 'Tolls_Amt': 4.15, 'Total_Amt': 29.27, 'Trip_Distance': 8.11, 'Trip_Dropoff_DateTime': '2009-06-13 12:47:00', 'Trip_Pickup_DateTime': '2009-06-13 12:28:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.756055, 'End_Lon': -73.988723, 'Fare_Amt': 4.5, 'Passenger_Count': 5, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.745353, 'Start_Lon': -73.99112, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 5.0, 'Trip_Distance': 0.99, 'Trip_Dropoff_DateTime': '2009-06-22 01:32:00', 'Trip_Pickup_DateTime': '2009-06-22 01:29:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.723562, 'End_Lon': -73.991198, 'Fare_Amt': 5.3, 'Passenger_Count': 2, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.740968, 'Start_Lon': -73.97859, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 5.3, 'Trip_Distance': 1.4, 'Trip_Dropoff_DateTime': '2009-06-10 06:20:00', 'Trip_Pickup_DateTime': '2009-06-10 06:18:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.771735, 'End_Lon': -73.979332, 'Fare_Amt': 4.9, 'Passenger_Count': 2, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.766685, 'Start_Lon': -73.965072, 'Tip_Amt': 1.0, 'Tolls_Amt': 0.0, 'Total_Amt': 5.9, 'Trip_Distance': 0.93, 'Trip_Dropoff_DateTime': '2009-06-13 12:43:00', 'Trip_Pickup_DateTime': '2009-06-13 12:38:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.722425, 'End_Lon': -73.997295, 'Fare_Amt': 7.7, 'Passenger_Count': 3, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.733143, 'Start_Lon': -74.006425, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 7.7, 'Trip_Distance': 1.36, 'Trip_Dropoff_DateTime': '2009-06-13 12:52:00', 'Trip_Pickup_DateTime': '2009-06-13 12:40:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.76503, 'End_Lon': -73.97721, 'Fare_Amt': 7.7, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.750635, 'Start_Lon': -73.99139, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 7.7, 'Trip_Distance': 1.99, 'Trip_Dropoff_DateTime': '2009-06-22 07:16:00', 'Trip_Pickup_DateTime': '2009-06-22 07:06:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.772183, 'End_Lon': -73.946773, 'Fare_Amt': 7.3, 'Passenger_Count': 2, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.757027, 'Start_Lon': -73.970343, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 7.8, 'Trip_Distance': 1.99, 'Trip_Dropoff_DateTime': '2009-06-10 02:40:00', 'Trip_Pickup_DateTime': '2009-06-10 02:33:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.714478, 'End_Lon': -74.003443, 'Fare_Amt': 5.7, 'Passenger_Count': 3, 'Payment_Type': 'CASH',  ...

# %%
import requests

BASE_API_URL = "https://us-central1-dlthub-analytics.cloudfunctions.net/data_engineering_zoomcamp_api"

def paginated_getter():
    page_number = 1
    while True:
        params = {'page': page_number}
        response = requests.get(BASE_API_URL, params=params)
        response.raise_for_status()
        page_json = response.json()
        print(f'Got page {page_number} with {len(page_json)} records')

        if page_json:
            yield page_json
            page_number += 1
        else:
            break


for page_data in paginated_getter():
    print(page_data)
    break

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator


def paginated_getter():
    client = RESTClient(
        base_url="https://us-central1-dlthub-analytics.cloudfunctions.net",
        # Define pagination strategy - page-based pagination
        paginator=PageNumberPaginator(   # <--- Pages are numbered (1, 2, 3, ...)
            base_page=1,   # <--- Start from page 1
            total_path=None    # <--- No total count of pages provided by API, pagination should stop when a page contains no result items
        )
    )

    for page in client.paginate("data_engineering_zoomcamp_api"):    # <--- API endpoint for retrieving taxi ride data
        yield page   # remember about memory management and yield data

for page_data in paginated_getter():
    print(page_data)
    break
# Out:
# [{'End_Lat': 40.742963, 'End_Lon': -73.980072, 'Fare_Amt': 45.0, 'Passenger_Count': 1, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.641525, 'Start_Lon': -73.787442, 'Tip_Amt': 9.0, 'Tolls_Amt': 4.15, 'Total_Amt': 58.15, 'Trip_Distance': 17.52, 'Trip_Dropoff_DateTime': '2009-06-14 23:48:00', 'Trip_Pickup_DateTime': '2009-06-14 23:23:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.740187, 'End_Lon': -74.005698, 'Fare_Amt': 6.5, 'Passenger_Count': 1, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.722065, 'Start_Lon': -74.009767, 'Tip_Amt': 1.0, 'Tolls_Amt': 0.0, 'Total_Amt': 8.5, 'Trip_Distance': 1.56, 'Trip_Dropoff_DateTime': '2009-06-18 17:43:00', 'Trip_Pickup_DateTime': '2009-06-18 17:35:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 1.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.718043, 'End_Lon': -74.004745, 'Fare_Amt': 12.5, 'Passenger_Count': 5, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.761945, 'Start_Lon': -73.983038, 'Tip_Amt': 2.0, 'Tolls_Amt': 0.0, 'Total_Amt': 15.5, 'Trip_Distance': 3.37, 'Trip_Dropoff_DateTime': '2009-06-10 18:27:00', 'Trip_Pickup_DateTime': '2009-06-10 18:08:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 1.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.739637, 'End_Lon': -73.985233, 'Fare_Amt': 4.9, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.749802, 'Start_Lon': -73.992247, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 5.4, 'Trip_Distance': 1.11, 'Trip_Dropoff_DateTime': '2009-06-14 23:58:00', 'Trip_Pickup_DateTime': '2009-06-14 23:54:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.730032, 'End_Lon': -73.852693, 'Fare_Amt': 25.7, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.776825, 'Start_Lon': -73.949233, 'Tip_Amt': 0.0, 'Tolls_Amt': 4.15, 'Total_Amt': 29.85, 'Trip_Distance': 11.09, 'Trip_Dropoff_DateTime': '2009-06-13 13:23:00', 'Trip_Pickup_DateTime': '2009-06-13 13:01:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.777537, 'End_Lon': -73.97686, 'Fare_Amt': 7.3, 'Passenger_Count': 2, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.790582, 'Start_Lon': -73.953652, 'Tip_Amt': 2.0, 'Tolls_Amt': 0.0, 'Total_Amt': 10.3, 'Trip_Distance': 2.1, 'Trip_Dropoff_DateTime': '2009-06-10 19:52:00', 'Trip_Pickup_DateTime': '2009-06-10 19:43:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 1.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.770277, 'End_Lon': -73.962125, 'Fare_Amt': 3.7, 'Passenger_Count': 1, 'Payment_Type': 'Credit', 'Rate_Code': None, 'Start_Lat': 40.767147, 'Start_Lon': -73.966408, 'Tip_Amt': 1.0, 'Tolls_Amt': 0.0, 'Total_Amt': 5.2, 'Trip_Distance': 0.4, 'Trip_Dropoff_DateTime': '2009-06-10 20:09:00', 'Trip_Pickup_DateTime': '2009-06-10 20:06:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.774043, 'End_Lon': -73.951465, 'Fare_Amt': 8.1, 'Passenger_Count': 2, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.76175, 'Start_Lon': -73.977773, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 8.6, 'Trip_Distance': 2.24, 'Trip_Dropoff_DateTime': '2009-06-14 21:08:00', 'Trip_Pickup_DateTime': '2009-06-14 20:57:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.5, 'vendor_name': 'VTS'}, {'End_Lat': 40.777985, 'End_Lon': -73.943683, 'Fare_Amt': 6.1, 'Passenger_Count': 1, 'Payment_Type': 'CASH', 'Rate_Code': None, 'Start_Lat': 40.766355, 'Start_Lon': -73.959832, 'Tip_Amt': 0.0, 'Tolls_Amt': 0.0, 'Total_Amt': 6.1, 'Trip_Distance': 1.48, 'Trip_Dropoff_DateTime': '2009-06-14 12:56:00', 'Trip_Pickup_DateTime': '2009-06-14 12:49:00', 'mta_tax': None, 'store_and_forward': None, 'surcharge': 0.0, 'vendor_name': 'VTS'}, {'End_Lat': 40.720052, 'End_Lon': -74.009823, 'Fare_Amt': 8.9, 'Passenger_Count': 1, 'Paymen ...

# %%
# %pip install dlt[duckdb]
# Out:
# Requirement already satisfied: dlt[duckdb] in d:\de-project-2024\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: PyYAML>=5.4.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (6.0.2)
# Requirement already satisfied: click>=7.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (8.1.8)
# Collecting duckdb>=0.9 (from dlt[duckdb])
#   Using cached duckdb-1.2.0-cp311-cp311-win_amd64.whl.metadata (995 bytes)
# Requirement already satisfied: fsspec>=2022.4.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (2025.2.0)
# Requirement already satisfied: gitpython>=3.1.29 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (3.1.44)
# Requirement already satisfied: giturlparse>=0.10.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (0.12.0)
# Requirement already satisfied: hexbytes>=0.2.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (1.3.0)
# Requirement already satisfied: humanize>=4.4.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (4.11.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (1.7.0)
# Requirement already satisfied: makefun>=1.15.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (1.15.6)
# Requirement already satisfied: orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (3.10.15)
# Requirement already satisfied: packaging>=21.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (24.2)
# Requirement already satisfied: pathvalidate>=2.5.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (3.2.3)
# Requirement already satisfied: pendulum>=2.1.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (3.0.0)
# Requirement already satisfied: pluggy>=1.3.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (1.5.0)
# Requirement already satisfied: pytz>=2022.6 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (2024.2)
# Requirement already satisfied: pywin32>=306 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (308)
# Requirement already satisfied: requests>=2.26.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (2.32.3)
# Requirement already satisfied: requirements-parser>=0.5.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (0.11.0)
# Requirement already satisfied: rich-argparse<2.0.0,>=1.6.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (1.7.0)
# Requirement already satisfied: semver>=3.0.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (3.0.4)
# Requirement already satisfied: setuptools>=65.6.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (75.8.0)
# Requirement already satisfied: simplejson>=3.17.5 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (3.19.3)
# Requirement already satisfied: tenacity>=8.0.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (9.0.0)
# Requirement already satisfied: tomlkit>=0.11.3 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (0.13.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (4.12.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (2024.2)
# Requirement already satisfied: win-precise-time>=1.4.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[duckdb]) (1.4.2)
# Requirement already satisfied: colorama in d:\de-project-2024\.venv\lib\site-packages (from click>=7.1->dlt[duckdb]) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\de-project-2024\.venv\lib\site-packages (from gitpython>=3.1.29->dlt[duckdb]) (4.0.12)
# Requirement already satisfied: ply in d:\de-project-2024\.venv\lib\site-packages (from jsonpath-ng>=1.5.3->dlt[duckdb]) (3.11)
# Requirement already satisfied: python-dateutil>=2.6 in d:\de-project-2024\.venv\lib\site-packages (from pendulum>=2.1.2->dlt[duckdb]) (2.9.0.post0)
# Requirement already satisfied: time-machine>=2.6.0 in d:\de-project-2024\.venv\lib\site-packages (from pendulum>=2.1.2->dlt[duckdb]) (2.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (2025.1.31)
# Requirement already satisfied: types-setuptools>=69.1.0 in d:\de-project-2024\.venv\lib\site-packages (from requirements-parser>=0.5.0->dlt[duckdb]) (75.8.0.20250210)
# Requirement already satisfied: rich>=11.0.0 in d:\de-project-2024\.venv\lib\site-packages (from rich-argparse<2.0.0,>=1.6.0->dlt[duckdb]) (13.9.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\de-project-2024\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[duckdb]) (5.0.2)
# Requirement already satisfied: six>=1.5 in d:\de-project-2024\.venv\lib\site-packages (from python-dateutil>=2.6->pendulum>=2.1.2->dlt[duckdb]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\de-project-2024\.venv\lib\site-packages (from rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[duckdb]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\de-project-2024\.venv\lib\site-packages (from rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[duckdb]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\de-project-2024\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[duckdb]) (0.1.2)
# Using cached duckdb-1.2.0-cp311-cp311-win_amd64.whl (11.4 MB)
# Installing collected packages: duckdb
# Successfully installed duckdb-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
item = page_data[0]
item
# Out:
# {'End_Lat': 40.742963,
#  'End_Lon': -73.980072,
#  'Fare_Amt': 45.0,
#  'Passenger_Count': 1,
#  'Payment_Type': 'Credit',
#  'Rate_Code': None,
#  'Start_Lat': 40.641525,
#  'Start_Lon': -73.787442,
#  'Tip_Amt': 9.0,
#  'Tolls_Amt': 4.15,
#  'Total_Amt': 58.15,
#  'Trip_Distance': 17.52,
#  'Trip_Dropoff_DateTime': '2009-06-14 23:48:00',
#  'Trip_Pickup_DateTime': '2009-06-14 23:23:00',
#  'mta_tax': None,
#  'store_and_forward': None,
#  'surcharge': 0.0,
#  'vendor_name': 'VTS'}

# %%
data = [
    {
        "vendor_name": "VTS",
        "record_hash": "b00361a396177a9cb410ff61f20015ad",
        "time": {
            "pickup": "2009-06-14 23:23:00",
            "dropoff": "2009-06-14 23:48:00"
        },
        "coordinates": {
            "start": {"lon": -73.787442, "lat": 40.641525},
            "end": {"lon": -73.980072, "lat": 40.742963}
        },
        "passengers": [
            {"name": "John", "rating": 4.9},
            {"name": "Jack", "rating": 3.9}
        ]
    }
]

# %%
data
# Out:
# [{'vendor_name': 'VTS',
#   'record_hash': 'b00361a396177a9cb410ff61f20015ad',
#   'time': {'pickup': '2009-06-14 23:23:00', 'dropoff': '2009-06-14 23:48:00'},
#   'coordinates': {'start': {'lon': -73.787442, 'lat': 40.641525},
#    'end': {'lon': -73.980072, 'lat': 40.742963}},
#   'passengers': [{'name': 'John', 'rating': 4.9},
#    {'name': 'Jack', 'rating': 3.9}]}]

# %%
import dlt

# Define a dlt pipeline with automatic normalization
pipeline = dlt.pipeline(
    pipeline_name="ny_taxi_data",
    destination="duckdb",
    dataset_name="taxi_rides",
)

# Run the pipeline with raw nested data
info = pipeline.run(data, table_name="rides", write_disposition="replace")

# Print the load summary
print(info)

print(pipeline.last_trace)
# Out:
# Pipeline ny_taxi_data load step completed in 1.16 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset taxi_rides
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi_data.duckdb location to store data
# Load package 1739430760.474601 is LOADED and contains no failed jobs
# Run started at 2025-02-13 07:12:40.288946+00:00 and COMPLETED in 1.73 seconds with 4 steps.
# Step extract COMPLETED in 0.10 seconds.
#
# Load package 1739430760.474601 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 0.06 seconds.
# Normalized data for the following tables:
# - rides: 1 row(s)
# - rides__passengers: 2 row(s)
# - _dlt_pipeline_state: 1 row(s)
#
# Load package 1739430760.474601 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 1.39 seconds.
# Pipeline ny_taxi_data load step completed in 1.16 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset taxi_rides
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi_data.duckdb location to store data
# Load package 1739430760.474601 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 1.73 seconds.
# Pipeline ny_taxi_data load step completed in 1.16 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset taxi_rides
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi_data.duckdb location to store data
# Load package 1739430760.474601 is LOADED and contains no failed jobs

# %%
pipeline.dataset(dataset_type="default").rides.df()
# Out:
#   vendor_name                       record_hash              time__pickup  \
# 0         VTS  b00361a396177a9cb410ff61f20015ad 2009-06-14 23:23:00+00:00
#
#               time__dropoff  coordinates__start__lon  coordinates__start__lat  \
# 0 2009-06-14 23:48:00+00:00               -73.787442                40.641525
#
#    coordinates__end__lon  coordinates__end__lat       _dlt_load_id  \
# 0             -73.980072              40.742963  1739430760.474601
#
#           _dlt_id
# 0  P0NkKZvRx32w3w

# %%
pipeline.dataset(dataset_type="default").rides__passengers.df()
# Out:
#    name  rating  _dlt_parent_id  _dlt_list_idx         _dlt_id
# 0  John     4.9  P0NkKZvRx32w3w              0  Gcm7Zdjqhj5oWA
# 1  Jack     3.9  P0NkKZvRx32w3w              1  V7xU4/4XHM2IKA

# %%
import duckdb

# 1. Create a connection to an in-memory DuckDB database
conn = duckdb.connect("ny_taxi_manual.db")

# 2. Create the rides Table
# Since our dataset has nested structures, we must manually flatten it before inserting data.
conn.execute("""
CREATE TABLE IF NOT EXISTS rides (
    record_hash TEXT PRIMARY KEY,
    vendor_name TEXT,
    pickup_time TIMESTAMP,
    dropoff_time TIMESTAMP,
    start_lon DOUBLE,
    start_lat DOUBLE,
    end_lon DOUBLE,
    end_lat DOUBLE
);
""")

# 3. Insert Data Manually
# Since JSON data has nested fields, we need to extract and transform them before inserting them into DuckDB.
data = [
    {
        "vendor_name": "VTS",
        "record_hash": "b00361a396177a9cb410ff61f20015ad",
        "time": {
            "pickup": "2009-06-14 23:23:00",
            "dropoff": "2009-06-14 23:48:00"
        },
        "coordinates": {
            "start": {"lon": -73.787442, "lat": 40.641525},
            "end": {"lon": -73.980072, "lat": 40.742963}
        }
    }
]

# Prepare data for insertion
flattened_data = [
    (
        ride["record_hash"],
        ride["vendor_name"],
        ride["time"]["pickup"],
        ride["time"]["dropoff"],
        ride["coordinates"]["start"]["lon"],
        ride["coordinates"]["start"]["lat"],
        ride["coordinates"]["end"]["lon"],
        ride["coordinates"]["end"]["lat"]
    )
    for ride in data
]

# Insert into DuckDB
conn.executemany("""
INSERT INTO rides (record_hash, vendor_name, pickup_time, dropoff_time, start_lon, start_lat, end_lon, end_lat)
VALUES (?, ?, ?, ?, ?, ?, ?, ?)
""", flattened_data)

print("Data successfully loaded into DuckDB!")


# 4. Query Data in DuckDB
# Now that the data is loaded, we can query it using DuckDB’s SQL engine.
df = conn.execute("SELECT * FROM rides").df()

conn.close()
# Out:
# Data successfully loaded into DuckDB!

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator


# Define the API resource for NYC taxi data
@dlt.resource(name="rides")   # <--- The name of the resource (will be used as the table name)
def ny_taxi():
    client = RESTClient(
        base_url="https://us-central1-dlthub-analytics.cloudfunctions.net",
        paginator=PageNumberPaginator(
            base_page=1,
            total_path=None
        )
    )

    for page in client.paginate("data_engineering_zoomcamp_api"):    # <--- API endpoint for retrieving taxi ride data
        yield page   # <--- yield data to manage memory


# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")

# run the pipeline with the new resource
load_info = pipeline.run(ny_taxi, write_disposition="replace")
print(load_info)

# explore loaded data
pipeline.dataset(dataset_type="default").rides.df()
# Out:
# Pipeline dlt_ipykernel_launcher load step completed in 0.98 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_ipykernel_launcher_dataset
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\dlt_ipykernel_launcher.duckdb location to store data
# Load package 1739432724.7907758 is LOADED and contains no failed jobs
#         end_lat    end_lon  fare_amt  passenger_count payment_type  start_lat  \
# 0     40.742963 -73.980072      45.0                1       Credit  40.641525
# 1     40.740187 -74.005698       6.5                1       Credit  40.722065
# 2     40.718043 -74.004745      12.5                5       Credit  40.761945
# 3     40.739637 -73.985233       4.9                1         CASH  40.749802
# 4     40.730032 -73.852693      25.7                1         CASH  40.776825
# ...         ...        ...       ...              ...          ...        ...
# 9995  40.783522 -73.970690       5.7                1         CASH  40.778560
# 9996  40.777200 -73.964197       4.1                1         CASH  40.779800
# 9997  40.780172 -73.957617       6.1                1         CASH  40.788388
# 9998  40.777342 -73.957242       5.7                1         CASH  40.773828
# 9999  40.757122 -73.986293       6.5                1       Credit  40.756313
#
#       start_lon  tip_amt  tolls_amt  total_amt  trip_distance  \
# 0    -73.787442      9.0       4.15      58.15          17.52
# 1    -74.009767      1.0       0.00       8.50           1.56
# 2    -73.983038      2.0       0.00      15.50           3.37
# 3    -73.992247      0.0       0.00       5.40           1.11
# 4    -73.949233      0.0       4.15      29.85          11.09
# ...         ...      ...        ...        ...            ...
# 9995 -73.953660      0.0       0.00       5.70           1.16
# 9996 -73.974297      0.0       0.00       4.10           0.89
# 9997 -73.976758      0.0       0.00       6.10           1.30
# 9998 -73.956690      0.0       0.00       6.20           0.97
# 9999 -73.972948      2.0       0.00       8.50           0.92
#
#         trip_dropoff_date_time     trip_pickup_date_time  surcharge  \
# 0    2009-06-14 23:48:00+00:00 2009-06-14 23:23:00+00:00        0.0
# 1    2009-06-18 17:43:00+00:00 2009-06-18 17:35:00+00:00        1.0
# 2    2009-06-10 18:27:00+00:00 2009-06-10 18:08:00+00:00        1.0
# 3    2009-06-14 23:58:00+00:00 2009-06-14 23:54:00+00:00        0.5
# 4    2009-06-13 13:23:00+00:00 2009-06-13 13:01:00+00:00        0.0
# ...                        ...                       ...        ...
# 9995 2009-06-19 11:28:00+00:00 2009-06-19 11:22:00+00:00        0.0
# 9996 2009-06-17 07:43:00+00:00 2009-06-17 07:41:00+00:00        0.0
# 9997 2009-06-19 11:46:00+00:00 2009-06-19 11:39:00+00:00        0.0
# 9998 2009-06-17 04:19:00+00:00 2009-06-17 04:13:00+00:00        0.5
# 9999 2009-06-17 08:34:00+00:00 2009-06-17 08:24:00+00:00        0.0
#
#      vendor_name        _dlt_load_id         _dlt_id  store_and_forward
# 0            VTS  1739432724.7907758  hdouQxRBm8FDAQ                NaN
# 1            VTS  1739432724.7907758  fO2sOrgYQqR1Rg                NaN
# 2            VTS  1739432724.7907758  1BwyLHjZxtqO0A                NaN
# 3            VTS  1739432724.7907758  bmoc+srkgqDDng                NaN
# 4            VTS  1739432724.7907758  MSYllGC4kP6hGw                NaN
# ...          ...                 ...             ...                ...
# 9995         VTS  1739432724.7907758  1Q1juMPZ2mWsfA                NaN
# 9996         VTS  1739432724.7907758  b2xWS+yJgBwcOA                NaN
# 9997         VTS  1739432724.7907758  UP99nbSehFuBzA                NaN
# 9998         VTS  1739432724.7907758  XhcrCgqR8GEXdQ                NaN
# 9999         VTS  1739432724.7907758  +AoNxf8QJB6xvw                NaN
#
# [10000 rows x 18 columns]

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator


@dlt.resource(name="rides", write_disposition="append")
def ny_taxi(
    cursor_date=dlt.sources.incremental(
        "Trip_Dropoff_DateTime",   # <--- field to track, our timestamp
        initial_value="2009-06-15",   # <--- start date June 15, 2009
        )
    ):
    client = RESTClient(
        base_url="https://us-central1-dlthub-analytics.cloudfunctions.net",
        paginator=PageNumberPaginator(
            base_page=1,
            total_path=None
        )
    )

    for page in client.paginate("data_engineering_zoomcamp_api"):
        yield page

# %%
# define new dlt pipeline
pipeline = dlt.pipeline(pipeline_name="ny_taxi", destination="duckdb", dataset_name="ny_taxi_data")

# run the pipeline with the new resource
load_info = pipeline.run(ny_taxi)
print(pipeline.last_trace)
# Out:
# Run started at 2025-02-13 07:56:30.704656+00:00 and COMPLETED in 22.68 seconds with 4 steps.
# Step extract COMPLETED in 21.44 seconds.
#
# Load package 1739433390.776956 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 0.50 seconds.
# Normalized data for the following tables:
# - rides: 5325 row(s)
# - _dlt_pipeline_state: 1 row(s)
#
# Load package 1739433390.776956 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 0.67 seconds.
# Pipeline ny_taxi load step completed in 0.64 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset ny_taxi_data
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi.duckdb location to store data
# Load package 1739433390.776956 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 22.68 seconds.
# Pipeline ny_taxi load step completed in 0.64 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset ny_taxi_data
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi.duckdb location to store data
# Load package 1739433390.776956 is LOADED and contains no failed jobs

# %%
with pipeline.sql_client() as client:
    res = client.execute_sql(
            """
            SELECT
            MIN(trip_dropoff_date_time)
            FROM rides;
            """
        )
    print(res)
# Out:
# [(datetime.datetime(2009, 6, 15, 0, 6, tzinfo=<UTC>),)]

# %%
# define new dlt pipeline
pipeline = dlt.pipeline(pipeline_name="ny_taxi", destination="duckdb", dataset_name="ny_taxi_data")


# run the pipeline with the new resource
load_info = pipeline.run(ny_taxi)
print(pipeline.last_trace)
# Out:
# Run started at 2025-02-13 07:57:56.569085+00:00 and COMPLETED in 21.91 seconds with 4 steps.
# Step extract COMPLETED in 21.77 seconds.
#
# Load package 1739433476.6558526 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 0.04 seconds.
# No data found to normalize
#
# Step load COMPLETED in 0.02 seconds.
# Pipeline ny_taxi load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi.duckdb location to store data
#
# Step run COMPLETED in 21.90 seconds.
# Pipeline ny_taxi load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi.duckdb location to store data

# %%
# %pip install dlt[bigquery]
# Out:
# Requirement already satisfied: dlt[bigquery] in d:\de-project-2024\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: PyYAML>=5.4.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (6.0.2)
# Requirement already satisfied: click>=7.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (8.1.8)
# Collecting db-dtypes>=1.2.0 (from dlt[bigquery])
#   Downloading db_dtypes-1.4.1-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: fsspec>=2022.4.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (2025.2.0)
# Collecting gcsfs>=2022.4.0 (from dlt[bigquery])
#   Downloading gcsfs-2025.2.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: gitpython>=3.1.29 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (3.1.44)
# Requirement already satisfied: giturlparse>=0.10.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (0.12.0)
# Collecting google-cloud-bigquery>=2.26.0 (from dlt[bigquery])
#   Downloading google_cloud_bigquery-3.29.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting grpcio>=1.50.0 (from dlt[bigquery])
#   Downloading grpcio-1.70.0-cp311-cp311-win_amd64.whl.metadata (4.0 kB)
# Requirement already satisfied: hexbytes>=0.2.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (1.3.0)
# Requirement already satisfied: humanize>=4.4.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (4.11.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (1.7.0)
# Requirement already satisfied: makefun>=1.15.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (1.15.6)
# Requirement already satisfied: orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (3.10.15)
# Requirement already satisfied: packaging>=21.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (24.2)
# Requirement already satisfied: pathvalidate>=2.5.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (3.2.3)
# Requirement already satisfied: pendulum>=2.1.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (3.0.0)
# Requirement already satisfied: pluggy>=1.3.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (1.5.0)
# Collecting pyarrow<18,>=12.0.0 (from dlt[bigquery])
#   Downloading pyarrow-17.0.0-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: pytz>=2022.6 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (2024.2)
# Requirement already satisfied: pywin32>=306 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (308)
# Requirement already satisfied: requests>=2.26.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (2.32.3)
# Requirement already satisfied: requirements-parser>=0.5.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (0.11.0)
# Requirement already satisfied: rich-argparse<2.0.0,>=1.6.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (1.7.0)
# Requirement already satisfied: semver>=3.0.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (3.0.4)
# Requirement already satisfied: setuptools>=65.6.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (75.8.0)
# Requirement already satisfied: simplejson>=3.17.5 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (3.19.3)
# Requirement already satisfied: tenacity>=8.0.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (9.0.0)
# Requirement already satisfied: tomlkit>=0.11.3 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (0.13.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (4.12.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (2024.2)
# Requirement already satisfied: win-precise-time>=1.4.2 in d:\de-project-2024\.venv\lib\site-packages (from dlt[bigquery]) (1.4.2)
# Requirement already satisfied: colorama in d:\de-project-2024\.venv\lib\site-packages (from click>=7.1->dlt[bigquery]) (0.4.6)
# Requirement already satisfied: pandas>=0.24.2 in d:\de-project-2024\.venv\lib\site-packages (from db-dtypes>=1.2.0->dlt[bigquery]) (2.2.3)
# Requirement already satisfied: numpy>=1.16.6 in d:\de-project-2024\.venv\lib\site-packages (from db-dtypes>=1.2.0->dlt[bigquery]) (2.2.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading aiohttp-3.11.12-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: decorator>4.1.2 in d:\de-project-2024\.venv\lib\site-packages (from gcsfs>=2022.4.0->dlt[bigquery]) (5.1.1)
# Collecting google-auth>=1.2 (from gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib (from gcsfs>=2022.4.0->dlt[bigquery])
#   Using cached google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-storage (from gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading google_cloud_storage-3.0.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\de-project-2024\.venv\lib\site-packages (from gitpython>=3.1.29->dlt[bigquery]) (4.0.12)
# Collecting google-api-core<3.0.0dev,>=2.11.1 (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Downloading google_api_core-2.24.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-cloud-core<3.0.0dev,>=2.4.1 (from google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0dev,>=2.0.0 (from google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in d:\de-project-2024\.venv\lib\site-packages (from google-cloud-bigquery>=2.26.0->dlt[bigquery]) (2.9.0.post0)
# Requirement already satisfied: ply in d:\de-project-2024\.venv\lib\site-packages (from jsonpath-ng>=1.5.3->dlt[bigquery]) (3.11)
# Requirement already satisfied: time-machine>=2.6.0 in d:\de-project-2024\.venv\lib\site-packages (from pendulum>=2.1.2->dlt[bigquery]) (2.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\de-project-2024\.venv\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (2025.1.31)
# Requirement already satisfied: types-setuptools>=69.1.0 in d:\de-project-2024\.venv\lib\site-packages (from requirements-parser>=0.5.0->dlt[bigquery]) (75.8.0.20250210)
# Requirement already satisfied: rich>=11.0.0 in d:\de-project-2024\.venv\lib\site-packages (from rich-argparse<2.0.0,>=1.6.0->dlt[bigquery]) (13.9.4)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading frozenlist-1.5.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading multidict-6.1.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading propcache-0.2.1-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading yarl-1.18.3-cp311-cp311-win_amd64.whl.metadata (71 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\de-project-2024\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[bigquery]) (5.0.2)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Downloading googleapis_common_protos-1.67.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Downloading proto_plus-1.26.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Downloading grpcio_status-1.70.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery])
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery])
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-resumable-media<3.0dev,>=2.0.0->google-cloud-bigquery>=2.26.0->dlt[bigquery])
#   Using cached google_crc32c-1.6.0-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: six>=1.5 in d:\de-project-2024\.venv\lib\site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\de-project-2024\.venv\lib\site-packages (from rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[bigquery]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\de-project-2024\.venv\lib\site-packages (from rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[bigquery]) (2.19.1)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib->gcsfs>=2022.4.0->dlt[bigquery])
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: mdurl~=0.1 in d:\de-project-2024\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->rich-argparse<2.0.0,>=1.6.0->dlt[bigquery]) (0.1.2)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery])
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2022.4.0->dlt[bigquery])
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading db_dtypes-1.4.1-py2.py3-none-any.whl (19 kB)
# Downloading gcsfs-2025.2.0-py2.py3-none-any.whl (35 kB)
# Downloading google_cloud_bigquery-3.29.0-py2.py3-none-any.whl (244 kB)
# Downloading grpcio-1.70.0-cp311-cp311-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 4.3/4.3 MB 28.7 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp311-cp311-win_amd64.whl (25.2 MB)
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    ------------ --------------------------- 7.9/25.2 MB 40.7 MB/s eta 0:00:01
#    ------------------------ --------------- 15.5/25.2 MB 42.4 MB/s eta 0:00:01
#    ------------------------------------ --- 22.8/25.2 MB 37.0 MB/s eta 0:00:01
#    ---------------------------------------- 25.2/25.2 MB 36.2 MB/s eta 0:00:00
# Downloading aiohttp-3.11.12-cp311-cp311-win_amd64.whl (442 kB)
# Downloading google_api_core-2.24.1-py3-none-any.whl (160 kB)
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Using cached google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Downloading google_cloud_storage-3.0.0-py2.py3-none-any.whl (173 kB)
# Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Downloading cachetools-5.5.1-py3-none-any.whl (9.5 kB)
# Downloading frozenlist-1.5.0-cp311-cp311-win_amd64.whl (51 kB)
# Using cached google_crc32c-1.6.0-cp311-cp311-win_amd64.whl (33 kB)
# Downloading googleapis_common_protos-1.67.0-py2.py3-none-any.whl (164 kB)
# Downloading grpcio_status-1.70.0-py3-none-any.whl (14 kB)
# Downloading multidict-6.1.0-cp311-cp311-win_amd64.whl (28 kB)
# Downloading propcache-0.2.1-cp311-cp311-win_amd64.whl (44 kB)
# Downloading proto_plus-1.26.0-py3-none-any.whl (50 kB)
# Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Downloading yarl-1.18.3-cp311-cp311-win_amd64.whl (91 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: pyasn1, pyarrow, protobuf, propcache, oauthlib, multidict, grpcio, google-crc32c, frozenlist, cachetools, attrs, aiohappyeyeballs, yarl, rsa, requests-oauthlib, pyasn1-modules, proto-plus, googleapis-common-protos, google-resumable-media, aiosignal, grpcio-status, google-auth, db-dtypes, aiohttp, google-auth-oauthlib, google-api-core, google-cloud-core, google-cloud-storage, google-cloud-bigquery, gcsfs
# Successfully installed aiohappyeyeballs-2.4.6 aiohttp-3.11.12 aiosignal-1.3.2 attrs-25.1.0 cachetools-5.5.1 db-dtypes-1.4.1 frozenlist-1.5.0 gcsfs-2025.2.0 google-api-core-2.24.1 google-auth-2.38.0 google-auth-oauthlib-1.2.1 google-cloud-bigquery-3.29.0 google-cloud-core-2.4.1 google-cloud-storage-3.0.0 google-crc32c-1.6.0 google-resumable-media-2.7.2 googleapis-common-protos-1.67.0 grpcio-1.70.0 grpcio-status-1.70.0 multidict-6.1.0 oauthlib-3.2.2 propcache-0.2.1 proto-plus-1.26.0 protobuf-5.29.3 pyarrow-17.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 requests-oauthlib-2.0.0 rsa-4.9 yarl-1.18.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator


@dlt.resource(name="rides", write_disposition="replace")
def ny_taxi():
    client = RESTClient(
        base_url="https://us-central1-dlthub-analytics.cloudfunctions.net",
        paginator=PageNumberPaginator(
            base_page=1,
            total_path=None
        )
    )

    for page in client.paginate("data_engineering_zoomcamp_api"):
        yield page

# %%
pipeline = dlt.pipeline(
    pipeline_name='taxi_data',
    destination='bigquery', # <--- to run pipeline in production
    dataset_name='taxi_rides',
)

# %%
import os
os.environ['Bigquery_credential'] = 'D:\\DE-Project-2024\\xzde-012625-08807b3aa202.json'

# %%
pipeline = dlt.pipeline(
    pipeline_name="taxi_data",
    destination="bigquery",
    dataset_name="taxi_rides",
    dev_mode=True,
)

info = pipeline.run(ny_taxi)
print(info)
# Out:
# d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\client.py:595: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\dbapi\cursor.py:220, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     219     else:
# --> 220         rows = client.query_and_wait(
#     221             formatted_operation,
#     222             job_config=config,
#     223             page_size=self.arraysize,
#     224         )
#     225 except google.cloud.exceptions.GoogleCloudError as exc:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\client.py:3611, in Client.query_and_wait(self, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
#    3607 job_config = _job_helpers.job_config_with_defaults(
#    3608     job_config, self._default_query_job_config
#    3609 )
# -> 3611 return _job_helpers.query_and_wait(
#    3612     self,
#    3613     query,
#    3614     job_config=job_config,
#    3615     location=location,
#    3616     project=project,
#    3617     api_timeout=api_timeout,
#    3618     wait_timeout=wait_timeout,
#    3619     retry=retry,
#    3620     job_retry=job_retry,
#    3621     page_size=page_size,
#    3622     max_results=max_results,
#    3623 )
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:509, in query_and_wait(client, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
#     508 if job_retry is not None:
# --> 509     return job_retry(do_query)()
#     510 else:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:450, in query_and_wait.<locals>.do_query()
#     449 if retry is not None:
# --> 450     response = retry(client._call_api)(
#     451         retry=None,  # We're calling the retry decorator ourselves.
#     452         span_name="BigQuery.query",
#     453         span_attributes=span_attributes,
#     454         method="POST",
#     455         path=path,
#     456         data=request_body,
#     457         timeout=api_timeout,
#     458     )
#     459 else:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\client.py:843, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     840     with create_span(
#     841         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     842     ):
# --> 843         return call()
#     845 return call()
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\_http\__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#
# Forbidden: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/xzde-20240114/queries?prettyPrint=false: Billing has not been enabled for this project. Enable billing at https://console.cloud.google.com/billing. DML queries are not allowed in the free tier. Set up a billing account to remove this restriction.
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\sql_client.py:416, in raise_database_error.<locals>._wrap_gen(self, *args, **kwargs)
#     415     self._ensure_native_conn()
# --> 416     return (yield from f(self, *args, **kwargs))
#     417 except Exception as ex:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\impl\bigquery\sql_client.py:221, in BigQuerySqlClient.execute_query(self, query, *args, **kwargs)
#     220 # if session exists give it a preference
# --> 221 curr.execute(query, db_args, job_config=self._session_query or self._default_query)
#     222 yield BigQueryDBApiCursorImpl(curr)  # type: ignore
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\dbapi\_helpers.py:496, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     495     raise exc_class(exc_msg)
# --> 496 return method(self, *args, **kwargs)
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\dbapi\cursor.py:189, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     188 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 189 self._execute(
#     190     formatted_operation, parameters, job_id, job_config, parameter_types
#     191 )
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\google\cloud\bigquery\dbapi\cursor.py:226, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     225 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 226     raise exceptions.DatabaseError(exc)
#     228 self._query_rows = rows
#
# DatabaseError: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/xzde-20240114/queries?prettyPrint=false: Billing has not been enabled for this project. Enable billing at https://console.cloud.google.com/billing. DML queries are not allowed in the free tier. Set up a billing account to remove this restriction.
#
# During handling of the above exception, another exception occurred:
#
# DatabaseTransientException                Traceback (most recent call last)
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:607, in Pipeline.load(self, destination, dataset_name, credentials, workers, raise_on_failed_jobs)
#     606 with signals.delayed_signals():
# --> 607     runner.run_pool(load_step.config, load_step)
#     608 info: LoadInfo = self._get_step_info(load_step)
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\common\runners\pool_runner.py:91, in run_pool(config, run_f)
#      90 logger.debug("Running pool")
# ---> 91 while _run_func():
#      92     # for next run
#      93     signals.raise_if_signalled()
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\common\runners\pool_runner.py:84, in run_pool.<locals>._run_func()
#      83 elif isinstance(run_f, Runnable):
# ---> 84     run_metrics = run_f.run(cast(TExecutor, pool))
#      85 else:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\load\load.py:638, in Load.run(self, pool)
#     637             self._step_info_start_load_id(load_id)
# --> 638         self.load_single_package(load_id, schema)
#     640 return TRunMetrics(False, len(self.load_storage.list_normalized_packages()))
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\load\load.py:527, in Load.load_single_package(self, load_id, schema)
#     525 if (expected_update := self.load_storage.begin_schema_update(load_id)) is not None:
#     526     # init job client
# --> 527     applied_update = init_client(
#     528         job_client,
#     529         schema,
#     530         new_jobs,
#     531         expected_update,
#     532         job_client.should_truncate_table_before_load,
#     533         (
#     534             job_client.should_load_data_to_staging_dataset
#     535             if isinstance(job_client, WithStagingDataset)
#     536             else None
#     537         ),
#     538         drop_tables=dropped_tables,
#     539         truncate_tables=truncated_tables,
#     540     )
#     542     # init staging client
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\load\utils.py:117, in init_client(job_client, schema, new_jobs, expected_update, truncate_filter, load_staging_filter, drop_tables, truncate_tables)
#     116 job_client.verify_schema(only_tables=tables_with_jobs | dlt_tables, new_jobs=new_jobs)
# --> 117 applied_update = _init_dataset_and_update_schema(
#     118     job_client,
#     119     expected_update,
#     120     tables_with_jobs | dlt_tables,
#     121     truncate_table_names,
#     122     drop_tables=drop_table_names,
#     123 )
#     125 # update the staging dataset if client supports this
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\load\utils.py:180, in _init_dataset_and_update_schema(job_client, expected_update, update_tables, truncate_tables, staging_info, drop_tables)
#     176 logger.info(
#     177     f"Client for {job_client.config.destination_type} will update schema to package schema"
#     178     f" {staging_text}"
#     179 )
# --> 180 applied_update = job_client.update_stored_schema(
#     181     only_tables=update_tables, expected_update=expected_update
#     182 )
#     183 if truncate_tables:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\job_client_impl.py:198, in SqlJobClientBase.update_stored_schema(self, only_tables, expected_update)
#     197     with self.maybe_ddl_transaction():
# --> 198         applied_update = self._execute_schema_update_sql(only_tables)
#     199 else:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\job_client_impl.py:502, in SqlJobClientBase._execute_schema_update_sql(self, only_tables)
#     501 self.sql_client.execute_many(sql_scripts)
# --> 502 self._update_schema_in_storage(self.schema)
#     503 return schema_update
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\job_client_impl.py:694, in SqlJobClientBase._update_schema_in_storage(self, schema)
#     693     schema_str = base64.b64encode(zlib.compress(schema_bytes, level=9)).decode("ascii")
# --> 694 self._commit_schema_update(schema, schema_str)
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\job_client_impl.py:700, in SqlJobClientBase._commit_schema_update(self, schema, schema_str)
#     699 # values =  schema.version_hash, schema.name, schema.version, schema.ENGINE_VERSION, str(now_ts), schema_str
# --> 700 self.sql_client.execute_sql(
#     701     f"INSERT INTO {name}({self.version_table_schema_columns}) VALUES (%s, %s, %s, %s, %s,"
#     702     " %s);",
#     703     schema.version,
#     704     schema.ENGINE_VERSION,
#     705     now_ts,
#     706     schema.name,
#     707     schema.stored_version_hash,
#     708     schema_str,
#     709 )
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\impl\bigquery\sql_client.py:202, in BigQuerySqlClient.execute_sql(self, sql, *args, **kwargs)
#     199 def execute_sql(
#     200     self, sql: AnyStr, *args: Any, **kwargs: Any
#     201 ) -> Optional[Sequence[Sequence[Any]]]:
# --> 202     with self.execute_query(sql, *args, **kwargs) as curr:
#     203         if not curr.description:
#
# File D:\Anaconda\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\destinations\sql_client.py:418, in raise_database_error.<locals>._wrap_gen(self, *args, **kwargs)
#     417 except Exception as ex:
# --> 418     raise self._make_database_exception(ex)
#
# DatabaseTransientException: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/xzde-20240114/queries?prettyPrint=false: Billing has not been enabled for this project. Enable billing at https://console.cloud.google.com/billing. DML queries are not allowed in the free tier. Set up a billing account to remove this restriction.
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# Cell In[38], line 8
#       1 pipeline = dlt.pipeline(
#       2     pipeline_name="taxi_data",
#       3     destination="bigquery",
#       4     dataset_name="taxi_rides",
#       5     dev_mode=True,
#       6 )
# ----> 8 info = pipeline.run(ny_taxi)
#       9 print(info)
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:225, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     222     if trace:
#     223         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 225     step_info = f(self, *args, **kwargs)
#     226     return step_info
#     227 except Exception as ex:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:274, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     266 @wraps(f)
#     267 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     268     # add section context to the container to be used by all configuration without explicit sections resolution
#     269     with inject_section(
#     270         ConfigSectionContext(
#     271             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     272         )
#     273     ):
# --> 274         return f(self, *args, **kwargs)
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:746, in Pipeline.run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     734     self.extract(
#     735         data,
#     736         table_name=table_name,
#    (...)
#     743         refresh=refresh or self.refresh,
#     744     )
#     745     self.normalize(loader_file_format=loader_file_format)
# --> 746     return self.load(destination, dataset_name, credentials=credentials)
#     747 else:
#     748     return None
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:225, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     222     if trace:
#     223         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 225     step_info = f(self, *args, **kwargs)
#     226     return step_info
#     227 except Exception as ex:
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:165, in with_state_sync.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     163 should_extract_state = may_extract_state and self.config.restore_from_destination
#     164 with self.managed_state(extract_state=should_extract_state):
# --> 165     return f(self, *args, **kwargs)
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:274, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     266 @wraps(f)
#     267 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     268     # add section context to the container to be used by all configuration without explicit sections resolution
#     269     with inject_section(
#     270         ConfigSectionContext(
#     271             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     272         )
#     273     ):
# --> 274         return f(self, *args, **kwargs)
#
# File d:\DE-Project-2024\.venv\Lib\site-packages\dlt\pipeline\pipeline.py:614, in Pipeline.load(self, destination, dataset_name, credentials, workers, raise_on_failed_jobs)
#     612 except Exception as l_ex:
#     613     step_info = self._get_step_info(load_step)
# --> 614     raise PipelineStepFailed(
#     615         self, "load", load_step.current_load_id, l_ex, step_info
#     616     ) from l_ex
#
# PipelineStepFailed: Pipeline execution failed at stage load when processing package 1739518641.398027 with exception:
#
# <class 'dlt.destinations.exceptions.DatabaseTransientException'>
# 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/xzde-20240114/queries?prettyPrint=false: Billing has not been enabled for this project. Enable billing at https://console.cloud.google.com/billing. DML queries are not allowed in the free tier. Set up a billing account to remove this restriction.

# %%
# !dlt --version
# Out:
# dlt 1.6.1

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator


# your code is here


pipeline = dlt.pipeline(
    pipeline_name="ny_taxi_pipeline",
    destination="duckdb",
    dataset_name="ny_taxi_data"
)

# %%
load_info = pipeline.run(ny_taxi)
print(load_info)
# Out:
# Pipeline ny_taxi_pipeline load step completed in 0.92 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset ny_taxi_data
# The duckdb destination used duckdb:///d:\DE-Project-2024\workshop1\ny_taxi_pipeline.duckdb location to store data
# Load package 1739520252.4216628 is LOADED and contains no failed jobs

# %%
import duckdb
#from google.colab import data_table
#data_table.enable_dataframe_formatter()

# A database '<pipeline_name>.duckdb' was created in working directory so just connect to it

# Connect to the DuckDB database
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# Set search path to the dataset
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")

# Describe the dataset
conn.sql("DESCRIBE").df()
# Out:
#            database        schema                 name  \
# 0  ny_taxi_pipeline  ny_taxi_data           _dlt_loads
# 1  ny_taxi_pipeline  ny_taxi_data  _dlt_pipeline_state
# 2  ny_taxi_pipeline  ny_taxi_data         _dlt_version
# 3  ny_taxi_pipeline  ny_taxi_data                rides
#
#                                         column_names  \
# 0  [load_id, schema_name, status, inserted_at, sc...
# 1  [version, engine_version, pipeline_name, state...
# 2  [version, engine_version, inserted_at, schema_...
# 3  [end_lat, end_lon, fare_amt, passenger_count, ...
#
#                                         column_types  temporary
# 0  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3  [DOUBLE, DOUBLE, DOUBLE, BIGINT, VARCHAR, DOUB...      False

# %%
df = pipeline.dataset(dataset_type="default").rides.df()
df
# Out:
#         end_lat    end_lon  fare_amt  passenger_count payment_type  start_lat  \
# 0     40.742963 -73.980072      45.0                1       Credit  40.641525
# 1     40.740187 -74.005698       6.5                1       Credit  40.722065
# 2     40.718043 -74.004745      12.5                5       Credit  40.761945
# 3     40.739637 -73.985233       4.9                1         CASH  40.749802
# 4     40.730032 -73.852693      25.7                1         CASH  40.776825
# ...         ...        ...       ...              ...          ...        ...
# 9995  40.783522 -73.970690       5.7                1         CASH  40.778560
# 9996  40.777200 -73.964197       4.1                1         CASH  40.779800
# 9997  40.780172 -73.957617       6.1                1         CASH  40.788388
# 9998  40.777342 -73.957242       5.7                1         CASH  40.773828
# 9999  40.757122 -73.986293       6.5                1       Credit  40.756313
#
#       start_lon  tip_amt  tolls_amt  total_amt  trip_distance  \
# 0    -73.787442      9.0       4.15      58.15          17.52
# 1    -74.009767      1.0       0.00       8.50           1.56
# 2    -73.983038      2.0       0.00      15.50           3.37
# 3    -73.992247      0.0       0.00       5.40           1.11
# 4    -73.949233      0.0       4.15      29.85          11.09
# ...         ...      ...        ...        ...            ...
# 9995 -73.953660      0.0       0.00       5.70           1.16
# 9996 -73.974297      0.0       0.00       4.10           0.89
# 9997 -73.976758      0.0       0.00       6.10           1.30
# 9998 -73.956690      0.0       0.00       6.20           0.97
# 9999 -73.972948      2.0       0.00       8.50           0.92
#
#         trip_dropoff_date_time     trip_pickup_date_time  surcharge  \
# 0    2009-06-14 23:48:00+00:00 2009-06-14 23:23:00+00:00        0.0
# 1    2009-06-18 17:43:00+00:00 2009-06-18 17:35:00+00:00        1.0
# 2    2009-06-10 18:27:00+00:00 2009-06-10 18:08:00+00:00        1.0
# 3    2009-06-14 23:58:00+00:00 2009-06-14 23:54:00+00:00        0.5
# 4    2009-06-13 13:23:00+00:00 2009-06-13 13:01:00+00:00        0.0
# ...                        ...                       ...        ...
# 9995 2009-06-19 11:28:00+00:00 2009-06-19 11:22:00+00:00        0.0
# 9996 2009-06-17 07:43:00+00:00 2009-06-17 07:41:00+00:00        0.0
# 9997 2009-06-19 11:46:00+00:00 2009-06-19 11:39:00+00:00        0.0
# 9998 2009-06-17 04:19:00+00:00 2009-06-17 04:13:00+00:00        0.5
# 9999 2009-06-17 08:34:00+00:00 2009-06-17 08:24:00+00:00        0.0
#
#      vendor_name        _dlt_load_id         _dlt_id  store_and_forward
# 0            VTS  1739520252.4216628  2iiX3vLcdDVPKw                NaN
# 1            VTS  1739520252.4216628  WQKvJgXUCW9S5g                NaN
# 2            VTS  1739520252.4216628  cKVMggb1zbyadg                NaN
# 3            VTS  1739520252.4216628  H0RvW/H9g17xJA                NaN
# 4            VTS  1739520252.4216628  +JZDHVd/Zgx87g                NaN
# ...          ...                 ...             ...                ...
# 9995         VTS  1739520252.4216628  3iLTY9cYstC/iQ                NaN
# 9996         VTS  1739520252.4216628  ZUz/ebZrefCfdQ                NaN
# 9997         VTS  1739520252.4216628  klCytBmTTOIGLQ                NaN
# 9998         VTS  1739520252.4216628  wGM2dmlVGmgGNg                NaN
# 9999         VTS  1739520252.4216628  38CG7VArUz+PUw                NaN
#
# [10000 rows x 18 columns]

# %%
with pipeline.sql_client() as client:
    res = client.execute_sql(
            """
            SELECT
            AVG(date_diff('minute', trip_pickup_date_time, trip_dropoff_date_time))
            FROM rides;
            """
        )
    # Prints column values of the first row
    print(res)
# Out:
# [(12.3049,)]
